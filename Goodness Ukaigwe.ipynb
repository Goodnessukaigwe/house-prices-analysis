# %%
import pandas as pd

# %%
house_prices = pd.read_csv('house_prices.csv')

# %%
house_prices
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %% [markdown]
# ## 1st Question

# %%
house_prices.head() #Display the first 5 rows
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
house_prices.shape #Display the number of rows and columns,Therefore there are 1460 rows and 81 columns
# Out:
# (1460, 81)

# %%
house_prices.info() # A concise summary of the data frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
house_prices.describe() #The summary statistics of the numerical data types of the Data frame
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %% [markdown]
# ## 2nd Question

# %%
house_prices.loc[house_prices['MSSubClass'] >= 50] #Extract data from The building class equal to or greater than 50
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1449  1450         180       RM         21.0     1533   Pave   NaN      Reg
# 1450  1451          90       RL         60.0     9000   Pave   NaN      Reg
# 1452  1453         180       RM         35.0     3675   Pave   NaN      Reg
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
#
# ...

# %%
#Dealing with the missing values in the Type of alley access 
house_prices['Alley'].isnull().sum() # Get the summary statistics of the missing data in alley
# Out:
# 1369

# %%
house_prices.drop('Alley', axis = 1, inplace = True) # Dropping the column cause it contain lots of missing values

# %%
house_prices
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
#Create two new columns named "BuiltBefore1980 & BuiltAfter1980", these columns should contain boolean values: True, if it was built before 1980 and False if it wasn't & True if it was built after 1980 and False if it wasn't.

# %%
house_prices['BuiltBefore1980']= house_prices['YearBuilt']#creating a  new column containing True or False values based on the column 'YearBulit'

# %%
house_prices.loc[house_prices['BuiltBefore1980'] <1980, 'BuiltBefore1980'] = True
house_prices.loc[house_prices['BuiltBefore1980'] >=1980, 'BuiltBefore1980'] = False

# %%
house_prices
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... PoolQC  Fence MiscFeature MiscVal  \
# ...

# %%
house_prices['BuiltAfter1980']=house_prices['YearBuilt']#creating a  new column containing True or False values based on the column 'YearBulit'

# %%
house_prices.loc[house_prices['BuiltAfter1980'] <1980, 'BuiltAfter1980'] = False
house_prices.loc[house_prices['BuiltAfter1980'] >=1980, 'BuiltAfter1980'] = True

# %%
house_prices
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ...  Fence MiscFeature MiscVal MoSold  \
# ...

# %%
#Encode the 'Month Sold' column with the proper months of the year
month_name = {1:'January', 2:'February',3:'March',4:'April',5:'May',6:'June',7:'July',8:'August',9:'September',10:'October',11:'November',12:'December'}
# create a dictionary

# %%
house_prices['MoSold']
# Out:
# 0        2
# 1        5
# 2        9
# 3        2
# 4       12
#         ..
# 1455     8
# 1456     2
# 1457     5
# 1458     4
# 1459     6
# Name: MoSold, Length: 1460, dtype: int64

# %%
house_prices['MoSold'] = house_prices['MoSold'].replace(month_name)

# %%
house_prices['MoSold']
# Out:
# 0        February
# 1             May
# 2       September
# 3        February
# 4        December
#           ...
# 1455       August
# 1456     February
# 1457          May
# 1458        April
# 1459         June
# Name: MoSold, Length: 1460, dtype: object

# %%
#Extract data of houses that were sold from 2006 to 2010 
house_prices.loc[(house_prices['YrSold']>= 2006)&(house_prices['YrSold']<=2010)]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ...  Fence MiscFeature MiscVal  \
# ...

# %%
house = house_prices.loc[(house_prices['YrSold']>= 2006)&(house_prices['YrSold']<=2010)]

# %%
house['YrSold'].unique()
# Out:
# array([2008, 2007, 2006, 2009, 2010], dtype=int64)

# %%
#Extract data of homes whose original construction date starts from 1981 
house_prices.loc[house_prices['YearBuilt'] ==1981]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 53      54          20       RL         68.0    50271   Pave      IR1
# 169    170          20       RL          NaN    16669   Pave      IR1
# 265    266          20       RL         78.0    12090   Pave      IR1
# 1044  1045          20       RL         80.0     9600   Pave      Reg
# 1429  1430          20       RL          NaN    12546   Pave      IR1
#
#      LandContour Utilities LotConfig  ...  Fence MiscFeature MiscVal  \
# 53           Low    AllPub    Inside  ...    NaN         NaN       0
# 169          Lvl    AllPub    Corner  ...    NaN         NaN       0
# 265          Lvl    AllPub    Inside  ...  GdPrv         NaN       0
# 1044         Lvl    AllPub    Inside  ...  MnPrv         NaN       0
# 1429         Lvl    AllPub    Corner  ...    NaN         NaN       0
#
#         MoSold YrSold SaleType  SaleCondition  SalePrice  BuiltBefore1980  \
# ...

# %%
#Encoding my personal rating in the column "Overall condition rating"

# %%
grades = {1:'Very Dissatisfied', 2:'Very Dissatisfied', 3:'Dissatisfied', 4:'Dissatisfied', 5:'Neutral', 6:'Satisfied', 7:'Satisfied', 8:'Very Satisfied', 9:'Very Satisfied', 10:'Very Satisfied'}
#create a dictionary

# %%
house_prices['OverallCond'] = house_prices['OverallCond'].replace(grades)

# %%
house_prices['OverallCond']
# Out:
# 0              Neutral
# 1       Very Satisfied
# 2              Neutral
# 3              Neutral
# 4              Neutral
#              ...
# 1455           Neutral
# 1456         Satisfied
# 1457    Very Satisfied
# 1458         Satisfied
# 1459         Satisfied
# Name: OverallCond, Length: 1460, dtype: object
